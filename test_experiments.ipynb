# %%
import experiments
import numpy as np

# %%
default_params = {
    'first': 0,
    'second': 4.
}

with experiments.new_experiment(id='test', default_params=default_params):
    experiments.log(key='loss', value=10., extra_params=1.)
    experiments.step()
    experiments.log(key='index', value=7., extra_params=2.)
    experiments.step()
    experiments.log(key='loss', value=1., extra_params=1.)
    experiments.step()
    experiments.log(key='index', value=12., extra_params=2.)
    print(experiments.query('key', 'value', constraints={'first': experiments.Leq(0)}))
# Out:
# [['loss', 'index', 'loss', 'index'], [10.0, 7.0, 1.0, 12.0]]
